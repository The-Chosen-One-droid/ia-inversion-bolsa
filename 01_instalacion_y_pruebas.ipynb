# %% [markdown]
# <a href="https://colab.research.google.com/github/The-Chosen-One-droid/ia-inversion-bolsa/blob/main/01_instalacion_y_pruebas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Instalamos yfinance (pandas, numpy y matplotlib ya vienen preinstalados en Colab)
# !pip install yfinance

# 2. Importamos las librerías clave
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

print("¡Todas las librerías se han instalado e importado correctamente!")
# Out:
# ...
# ¡Todas las librerías se han instalado e importado correctamente!
